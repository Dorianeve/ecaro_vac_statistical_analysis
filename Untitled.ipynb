# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = "data/metadata/airtable_records.csv"
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to get an overview of the data
print(df.head())
# Out:
#                                                 Tags  \
# 0  ['2015', '2016', '2017', '2018', '2019', '2020...
# 1  ['2013', '2014', '2016', '2017', '2018', '2019...
# 2                                           ['2018']
# 3                                           ['2006']
# 4                                   ['2015', '2018']
#
#                                            Countries  \
# 0  ['recw9PiDwWLnV9w6V', 'recD7yEZsLX0AeQCY', 're...
# 1                              ['recZslZUm9qXK3tZp']
# 2  ['reca5LhwpMPGObRok', 'recA6MMaVV5a6FPai', 're...
# 3                              ['recBwqYAOhM5RuE58']
# 4  ['rec9MEnT9ARANCrpx', 'recPIePM0Wn1Cw0ML', 're...
#
#                                                 Name  Quality checked  \
# 0  Victims of intentional homicide and sexual exp...             True
# 1  Number of offences and rates per million popul...             True
# 2  Percentage of students (13-15 years) who repor...             True
# 3  Percentage of students (13-15 years) who repor...             True
# 4  Percentage of 15-year-old students who report ...             True
#
#    FileNumer            Selected for         ICVAC Category  \
# 0        1.0  ['Analysis', 'Trends']  ['recXtTxA6ggNyMxpM']
# 1        4.0                     NaN  ['recXtTxA6ggNyMxpM']
# 2        5.0            ['Analysis']  ['recIF03y4u9mmenxy']
# 3        6.0            ['Analysis']  ['recIF03y4u9mmenxy']
# 4        7.0            ['Analysis']  ['recIF03y4u9mmenxy']
#
#            Data provider                                              Notes  \
# 0  ['rec4i9AubnnTbFpKm']                          0 - 15 age\n15 - 19 age\n
# 1  ['reci7PM7ne4xZyfLN']                        [ ] Age 1 - 4 - 15 - 24\n\n
# 2  ['rechvPDOnRP36ZJVF']                                                NaN
# 3  ['recVHDCtHHtLqrcav']                                                NaN
# 4  ['recrYRsuykOrzvT4h']  Observation footnote\n[ ] Data did not meet th...
#
#   GenderDisaggregation  ...                             Provider  \
# 0                 True  ...                             Eurostat
# 1                 True  ...  Office for National Statistics (UK)
# 2                 True  ...                               UNICEF
# 3                 True  ...                                  WHO
# 4                 True  ...                                 OECD
#
#                                               Source  \
# 0                            eurostat - Data Browser
# 1                                   UK - NSO website
# 2                                TransMonEE Database
# 3                          TransMonEE Database, GSHS
# 4  OECD Programme for International Student Asses...
#
#                      Category  \
# 0  Violent killing of a child
# 1  Violent killing of a child
# 2        Composite phoenomena
# 3        Composite phoenomena
# 4        Composite phoenomena
#
#                                              Level_2  \
# 0  AV - Age of the victim, SV - Sex of the victim...
# 1     AV - Age of the victim, SV - Sex of the victim
# 2     AV - Age of the victim, SV - Sex of the victim
# 3     AV - Age of the victim, SV - Sex of the victim
# 4  AV - Age of the victim, SV - Sex of the victim...
#
#                                              Country  \
# 0  Türkiye, Germany, France, Italy, Spain, Poland...
# 1  United Kingdom of Great Britain and Northern I...
# 2  Albania, Armenia, Austria, Azerbaijan, Belgium...
# 3                                         Tajikistan
# 4  Austria, Belgium, Bulgaria, Switzerland, Czech...
#
#                                          Aggregation  \
# 0  4 - EUROSTAT - Victims of intentional homicide...
# 1                                                NaN
# 2  18 - TRANSMONEE - Percentage of students (13-1...
# 3  18 - TRANSMONEE - Percentage of students (13-1...
# 4  11 - PISA - Percentage of 15-year-old students...
#
#                                                 ISO3 ICVAC code  \
# 0  ['TUR', 'DEU', 'FRA', 'ITA', 'ESP', 'POL', 'RO...        [1]
# 1                                            ['GBR']        [1]
# 2  ['ALB', 'ARM', 'AUT', 'AZE', 'BEL', 'BGR', 'BI...       [10]
# 3                                            ['TJK']       [10]
# 4  ['AUT', 'BEL', 'BGR', 'CHE', 'CZE', 'DEU', 'DN...       [10]
#
#   Notes category  if composite
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
#
# [5 rows x 32 columns]

# %%
# Step 2: Split and explode 'Categories' to count occurrences by 'Category'
df['Category'] = df['Category'].str.split(', ')

# Explode 'Categories' column
df_category = df.explode('Category')  # Explode 'Categories' only

# Group by 'Category' and count occurrences
data_type_by_category = df_category['Category'].value_counts().reset_index(name='Count')
data_type_by_category.columns = ['Category', 'Count']

# Display the count of occurrences by 'Category'
print("\nCount of occurrences by Category:")
print(data_type_by_category)
data_type_by_category.to_csv('data/metadata/type_by_category.csv', index=False)
# Out:
# Count of occurrences by Category:
#                                             Category  Count
# 0  Other acts of violence against a child not els...    112
# 1                  Physical violence against a child     86
# 2                               Composite phoenomena     84
# 3                    Sexual violence against a child     81
# 4             Psychological violence against a child     61
# 5                         Violent killing of a child     18
# 6                                 Neglect of a child      6
